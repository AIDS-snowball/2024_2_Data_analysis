# %%
users_2023 = df_2023.loc[:, 'A163'].sum()
users_2022 = df_2022.loc[:, 'A163'].sum()
users_2021 = df_2021.loc[:, 'A163'].sum()
users_2020 = df_2020.loc[:, 'A163'].sum()
users_2019 = df_2019.loc[:, 'A160'].sum()
users_2018 = df_2018.loc[:, 'A150'].sum()
users_2017 = df_2017.loc[:, 'A150'].sum()

users = []
users.append(users_2017)
users.append(users_2018)
users.append(users_2019)
users.append(users_2020)
users.append(users_2021)
users.append(users_2022)
users.append(users_2023)

# %%
programs_2023 = df_2023.loc[:, ('A248', 'A250', 'A252','A254','A256','A258','A260','A262')].sum().sum()
programs_2022 = df_2022.loc[:, ('A248', 'A250', 'A252','A254','A256','A258','A260','A262')].sum().sum()
programs_2021 = df_2021.loc[:, ('A248', 'A250', 'A252','A254','A256','A258','A260','A262')].sum().sum()
programs_2020 = df_2020.loc[:, ('A246', 'A248', 'A250','A252','A254','A256','A258','A260')].sum().sum()
programs_2019 = df_2019.loc[:, 'A208'].sum().sum()
programs_2018 = df_2018.loc[:, 'A198'].sum().sum()
programs_2017 = df_2017.loc[:, 'A198'].sum().sum()

programs = []
programs.append(programs_2017)
programs.append(programs_2018)
programs.append(programs_2019)
programs.append(programs_2020)
programs.append(programs_2021)
programs.append(programs_2022)
programs.append(programs_2023)

# %%
import numpy as np
import matplotlib.pyplot as plt
from adjustText import adjust_text
import matplotlib.font_manager as fm

plt.rcParams['font.family'] = 'AppleGothic'


#plt.rcParams['figure.dpi'] = 300 

X = np.array(programs[3:])
y = np.array(users[3:])
years = [2020, 2021, 2022, 2023]

plt.figure(figsize=(10, 6))

plt.plot(X, y, color='#FFC260', label='Data Line', linewidth=2)

plt.scatter(X, y, color='#FFC260', label='Data Points', s=50, zorder=5)

plt.fill_between(X, y, color='#FFD942', alpha=0.5)

texts = []
for i, year in enumerate(years):
    texts.append(plt.text(X[i], y[i], str(year), fontsize=10, ha='right', color='black', alpha=0.8))

adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray', lw=0.5))

plt.title('도서관 내 프로그램 수와 도서관 회원수의 상관관계', fontsize=16)
plt.xlabel('programs', fontsize=14)
plt.ylabel('users', fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()
