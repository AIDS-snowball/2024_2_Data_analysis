# %% [markdown]
# <a href="https://colab.research.google.com/github/iamAnnakim/2024_2_Data_analysis/blob/main/%EA%B9%80%EC%9D%80%EA%B2%B0/2%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01-3 이 도서가 얼마나 인기가 좋을까요?

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://nbviewer.jupyter.org/github/rickiepark/hg-da/blob/main/01-3.ipynb"><img src="https://jupyter.org/assets/share.png" width="61" />주피터 노트북 뷰어로 보기</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/rickiepark/hg-da/blob/main/01-3.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />구글 코랩(Colab)에서 실행하기</a>
#   </td>
# </table>

# %% [markdown]
# ## 도서 데이터 찾기

# %% [markdown]
# [공공데이터포털](https://www.data.go.kr/)
#
# 도서관 정보나루의 [남산도서관 장서/대출 목록](https://www.data4library.kr/openDataV?libcode=4707)

# %% [markdown]
# ## 코랩에서 데이터 확인하기

# %%
import gdown

gdown.download('https://bit.ly/3eecMKZ',
               '남산도서관 장서 대출목록 (2021년 04월).csv', quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3eecMKZ
# To: /content/남산도서관 장서 대출목록 (2021년 04월).csv
# 100%|██████████| 58.1M/58.1M [00:00<00:00, 141MB/s]
# '남산도서관 장서 대출목록 (2021년 04월).csv'

# %% [markdown]
# ## 파이썬으로 CSV 파일 출력하기

# %%
with open('남산도서관 장서 대출목록 (2021년 04월)2.csv') as f:
    print(f.readline())
# Out:
# ﻿번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자

# %%
import chardet

with open('남산도서관 장서 대출목록 (2021년 04월).csv', mode='rb') as f:
    d = f.readline()

print(chardet.detect(d))
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}

# %%
with open('남산도서관 장서 대출목록 (2021년 04월)2.csv', encoding='euc-kr') as f:
    print(f.readline())
    print(f.readline())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-11-5d1879fe798e> in <cell line: 1>()
#       1 with open('남산도서관 장서 대출목록 (2021년 04월)2.csv', encoding='euc-kr') as f:
# ----> 2     print(f.readline())
#       3     print(f.readline())
#
# UnicodeDecodeError: 'euc_kr' codec can't decode byte 0xb2 in position 4: illegal multibyte sequence

# %%
import os
import glob
import unicodedata

for filename in glob.glob('*.csv'):
  nfc_filename = unicodedata.normalize('NFC', filename)
  os.rename(filename, nfc_filename)

# %% [markdown]
# ## 데이터프레임 다루기: 판다스

# %%
import pandas as pd

# %%
df = pd.read_csv('남산도서관 장서 대출목록 (2021년 04월).csv', encoding='euc-kr')
# Out:
# <ipython-input-6-e68e0ab15bf0>:1: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('남산도서관 장서 대출목록 (2021년 04월).csv', encoding='euc-kr')

# %%
df = pd.read_csv('남산도서관 장서 대출목록 (2021년 04월).csv', encoding='euc-kr',
                 low_memory=False)

# %%
df.tail(10)
# Out:
#             번호                  도서명                저자     출판사  발행년도  \
# 401672  401673  미애와 루이, 318일간의 버스여행  최미애 글;장 루이 볼프 사진      자인  2003
# 401673  401674          소설의 사회사 비교론            조동일 지음   지식산업사  2001
# 401674  401675            음악이 있는 풍경            김정환 지음  이론과 실천  1998
# 401675  401676                   시귀  오노 후유미 지음;임희선 옮김      들녘  1999
# 401676  401677                  큰오빠            박정근 지음   우리문학사  1998
# 401677  401678              韓國現代詩大系            채만묵 編著   한국문화사  1996
# 401678  401679                뉴 웨이브        제임스 모나코 지음     한나래  1996
# 401679  401680         (최인훈 장편소설)화두            최인훈 지음     민음사  1994
# 401680  401681         독일 문학과 세계 문학            吳漢鎭 編著      벽호  1995
# 401681  401682           참으로 소중한 생각            김일상 지음     동문사  1995
#
#                  ISBN          세트 ISBN 부가기호  권   주제분류번호  도서권수  대출건수  \
# 401672  9788989276210  9788989276210.0    0  1   980.24     0     0
# 401673  9788942340262  9788942300365.0  NaN  3    809.3     1     0
# 401674  9788931370010  9788931370027.0  NaN  2    670.4     1     0
# 401675  9788975271366  9788975271335.0    (  3    833.6     0     0
# 401676  9788974231323  9788974231309.0  NaN  2    813.6     2     0
# 401677  9788977352971  9788977352988.0  NaN  3  811.608     1     0
# 401678  9788985367448  9788985367424.0  NaN  2   688.04     1     0
# 401679  9788937401596  9788937401589.0  NaN  2    813.6     1     0
# 401680  9788947700368  9788947700405.0  NaN  3   809.05     2     0
# 401681  9788970610092  9788970610092.0    0  1    814.6     0     0
#
#               등록일자  Unnamed: 13
# 401672  1970-01-01          NaN
# 401673  1970-01-01          NaN
# 401674  1970-01-01          NaN
# 401675  1970-01-01          NaN
# 401676  1970-01-01          NaN
# 401677  1970-01-01          NaN
# 401678  1970-01-01          NaN
# 401679  1970-01-01          NaN
# 401680  1970-01-01          NaN
# 401681  1970-01-01          NaN

# %%
df = pd.read_csv('남산도서관 장서 대출목록 (2021년 04월).csv', encoding='euc-kr',
                 dtype={'ISBN': str, '세트 ISBN': str, '주제분류번호': str})
df2=df.head(5)

# %%
df2
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN

# %%
df2.to_csv('ns_202104.csv',low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-853fdfccf5f8> in <cell line: 1>()
# ----> 1 df2.to_csv('ns_202104.csv',low_memory=False)
#
# TypeError: NDFrame.to_csv() got an unexpected keyword argument 'low_memory'

# %%
with open('ns_202104.csv') as f:
    for i in range(3):
        print(f.readline(), end='')
# Out:
# ,번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,Unnamed: 13
# 0,1,인공지능과 흙,김동훈 지음,민음사,2021,9788937444319,,,,,1,0,2021-03-19,
# 1,2,가짜 행복 권하는 사회,김태형 지음,갈매나무,2021,9791190123969,,,,,1,0,2021-03-19,

# %%
ns_df = pd.read_csv('ns_202104.csv', low_memory=False)
ns_df.head()
# Out:
#    Unnamed: 0  번호                    도서명                저자    출판사  발행년도  \
# 0           0   1                인공지능과 흙            김동훈 지음    민음사  2021
# 1           1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021
# 2           2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021
# 3           3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021
# 4           4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021
#
#             ISBN  세트 ISBN  부가기호   권  주제분류번호  도서권수  대출건수        등록일자  \
# 0  9788937444319      NaN   NaN NaN     NaN     1     0  2021-03-19
# 1  9791190123969      NaN   NaN NaN     NaN     1     0  2021-03-19
# 2  9788968332982      NaN   NaN NaN     NaN     1     0  2021-03-19
# 3  9788970759906      NaN   NaN NaN     NaN     1     0  2021-03-19
# 4  9788934990833      NaN   NaN NaN     NaN     1     0  2021-03-19
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
ns_df = pd.read_csv('ns_202104.csv', index_col=0, low_memory=False)
ns_df.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN

# %%
df.to_csv('ns_202104.csv', index=False)

# %%
# 코랩을 사용하는 경우 xlsxwriter 패키지를 설치해 주세요.
# !pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.1.9-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.1.9

# %%
ns_df.to_excel('ns_202104.xlsx', index=False, engine='xlsxwriter')
